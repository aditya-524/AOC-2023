# %% [markdown]
# ## Day 1

# %% [markdown]
# #### --- Day 1: Trebuchet?! ---
# Something is wrong with global snow production, and you've been selected to take a look. The Elves have even given you a map; on it, they've used stars to mark the top fifty locations that are likely to be having problems.
#
# You've been doing this long enough to know that to restore snow operations, you need to check all fifty stars by December 25th.
#
# Collect stars by solving puzzles. Two puzzles will be made available on each day in the Advent calendar; the second puzzle is unlocked when you complete the first. Each puzzle grants one star. Good luck!
#
# You try to ask why they can't just use a weather machine ("not powerful enough") and where they're even sending you ("the sky") and why your map looks mostly blank ("you sure ask a lot of questions") and hang on did you just say the sky ("of course, where do you think snow comes from") when you realize that the Elves are already loading you into a trebuchet ("please hold still, we need to strap you in").
#
# As they're making the final adjustments, they discover that their calibration document (your puzzle input) has been amended by a very young Elf who was apparently just excited to show off her art skills. Consequently, the Elves are having trouble reading the values on the document.
#
# The newly-improved calibration document consists of lines of text; each line originally contained a specific calibration value that the Elves now need to recover. On each line, the calibration value can be found by combining the first digit and the last digit (in that order) to form a single two-digit number.
#
# For example:
#
# 1abc2
# pqr3stu8vwx
# a1b2c3d4e5f
# treb7uchet
# In this example, the calibration values of these four lines are 12, 38, 15, and 77. Adding these together produces 142.
#
# Consider your entire calibration document. What is the sum of all of the calibration values?

# %%
summation = 0
file = open('input.txt', 'r')
for line in file:
    num_list = []
    line_actual = line.strip()
    for i in line_actual:
        if i.isdigit():
            num_list.append(i)
    num = int(num_list[0] + num_list[-1])       
    # print(f"Line : {line_actual} \n Number: {num} ") # To check the output
    summation += num
file.close()
print(summation)
# Out:
# 55108

# %% [markdown]
# #### --- Part Two ---
# Your calculation isn't quite right. It looks like some of the digits are actually spelled out with letters: one, two, three, four, five, six, seven, eight, and nine also count as valid "digits".
#
# Equipped with this new information, you now need to find the real first and last digit on each line. For example:
#
# two1nine
# eightwothree
# abcone2threexyz
# xtwone3four
# 4nineeightseven2
# zoneight234
# 7pqrstsixteen
# In this example, the calibration values are 29, 83, 13, 24, 42, 14, and 76. Adding these together produces 281.
#
# What is the sum of all of the calibration values?

# %%
### Wrong Approach

word_to_num = {
    'zero': '0',
    'one': '1',
    'two': '2',
    'three': '3',
    'four': '4',
    'five': '5',
    'six': '6',
    'seven': '7',
    'eight': '8',
    'nine': '9'
}
summation = 0
file = open('test.txt', 'r')

for line in file:
    num_list = []
    line_actual = line.strip()
    print(f"Line : {line_actual}")
    for word, num in word_to_num.items():
        line_actual = line_actual.replace(word, num)
            
    for i in line_actual:

        if i.isdigit():
            num_list.append(i)
    num = int(num_list[0] + num_list[-1])       
    print(f"Number: {num} ") # To check the output
    summation += num
file.close()
print(summation)
# Out:
# Line : two1nine
# Number: 29
# Line : eightwothree
# Number: 23
# Line : abcone2threexyz
# Number: 13
# Line : xtwone3four
# Number: 14
# Line : 4nineeightseven2
# Number: 42
# Line : zoneight234
# Number: 14
# Line : 7pqrstsixteen
# Number: 76
# 211

# %%
## Accurate Approach : Copilot assisted
word_to_num = {
    'zero': '0',
    'one': '1',
    'two': '2',
    'three': '3',
    'four': '4',
    'five': '5',
    'six': '6',
    'seven': '7',
    'eight': '8',
    'nine': '9'
}

summation = 0
file = open('input.txt', 'r')

for line in file:
    line_actual = line.strip()
    print(f"Line : {line_actual}")
    
    first_pos = len(line_actual)
    last_pos = -1
    first_num = last_num = None

    # Check for digit characters
    for i in range(len(line_actual)):
        if line_actual[i].isdigit():
            if i < first_pos:
                first_pos = i
                first_num = line_actual[i]
            if i > last_pos:
                last_pos = i
                last_num = line_actual[i]

    # Check for number words
    for word, num in word_to_num.items():
        if word in line_actual:
            first_pos_word = line_actual.index(word)
            last_pos_word = line_actual.rindex(word) + len(word) - 1

            if first_pos_word < first_pos:
                first_pos = first_pos_word
                first_num = num

            if last_pos_word > last_pos:
                last_pos = last_pos_word
                last_num = num

    if first_num is not None and last_num is not None:
        num = int(first_num + last_num)
        print(f"Number: {num}")
        summation += num

file.close()
print(summation)
# Out:
# Line : gsjgklneight6zqfz
# Number: 86
# Line : 7one718onegfqtdbtxfcmd
# Number: 71
# Line : xvtfhkm8c9
# Number: 89
# Line : 914two8
# Number: 98
# Line : vxzzvdhfqfsix83c1ttvbbstxgdrkfcnmm3
# Number: 63
# Line : 76mkvhmbkpm
# Number: 76
# Line : 8sixssmlzlhrnineggmrvg6
# Number: 86
# Line : threeninedtr7219
# Number: 39
# Line : two2geight
# Number: 28
# Line : 3nine9fivetwo9twohxhc8
# Number: 38
# Line : llbfmnzzntdcfbslcl3xxvz
# Number: 33
# Line : two3leighttvpkfmjhhonefour
# Number: 24
# Line : 1b9four
# Number: 14
# Line : fivefdlqonesj2six
# Number: 56
# Line : hfptgztwosix8
# Number: 28
# Line : fourkcxqfgxbsvjj3472
# Number: 42
# Line : xhzs7rdphtxhtwo
# Number: 72
# Line : eightthree51
# Number: 81
# Line : 3nmronemlqzfxgonepkh
# Number: 31
# Line : 9vnxqtjjrsg
# Number: 99
# Line : 533fivesixrvqfxjrdhl
# Number: 56
# Line : bkrljtkjb42fqnp
# Number: 42
# Line : 4mrh734
# Number: 44
# Line : threefourfive83l
# Number: 33
# Line : lcjftnpqfourfivesixtwof3
# Number: 43
# ...
